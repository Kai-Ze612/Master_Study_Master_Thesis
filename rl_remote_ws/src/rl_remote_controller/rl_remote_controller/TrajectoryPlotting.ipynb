# %%
# Create an ideal path for comparison with the implemented trajectory 
import sys
import os
import numpy as np
import matplotlib.pyplot as plt

path = os.path.abspath('/media/kai/Kai_Backup/Master_Study/Master_Thesis/Master_Study_Master_Thesis/fr3_mujoco_ws/src/franka_mujoco_controller/franka_mujoco_controller')
sys.path.append(path)

from TrajectoryGenerator import TrajectoryGenerator

# Create instance without ROS2 (just for using the trajectory function)
traj_gen = TrajectoryGenerator.__new__(TrajectoryGenerator)  # Create without calling __init__

# Generate trajectory data
time_points = np.arange(0, 40.1, 0.1)  # 0 to 40 seconds, 0.1s intervals
positions = []

for t in time_points:
    pos = traj_gen.generate_figure8_trajectory(t)
    positions.append(pos)

positions = np.array(positions)

# Extract X, Y, Z coordinates
x_coords = positions[:, 0]
y_coords = positions[:, 1] 
z_coords = positions[:, 2]

# Create comprehensive plots
fig = plt.figure(figsize=(16, 12))

## 3D Trajectory Plot
ax1 = fig.add_subplot(2, 3, 1, projection='3d') ## 2 * 3 grid, first subplot is 3D
ax1.plot(x_coords, y_coords, z_coords, 'b-', linewidth=2, label='Figure-8 Trajectory')
ax1.scatter(x_coords[0], y_coords[0], z_coords[0], color='green', s=100, label='Start')
ax1.scatter(x_coords[-1], y_coords[-1], z_coords[-1], color='red', s=100, label='End')

ax1.set_xlabel('X (m)')
ax1.set_ylabel('Y (m)')
ax1.set_zlabel('Z (m)')
ax1.set_title('3D Figure-8 Trajectory')
ax1.legend()
ax1.grid(True)

# XY Plane View (Top view)
ax2 = fig.add_subplot(2, 3, 2)
ax2.plot(x_coords, y_coords, 'b-', linewidth=2)
ax2.scatter(x_coords[0], y_coords[0], color='green', s=100, label='Start')
ax2.scatter(x_coords[-1], y_coords[-1], color='red', s=100, label='End')
ax2.set_xlabel('X (m)')
ax2.set_ylabel('Y (m)')
ax2.set_title('XY Plane View (Top View)')
ax2.grid(True)
ax2.axis('equal')
ax2.legend()

# Save trajectory data for later comparison
trajectory_data = {
    'time': time_points,
    'positions': positions,
}

# %%
# Trajectory data for local robot
import os
import numpy as np
import matplotlib.pyplot as plt
from rosbags.rosbag2 import Reader
from rosbags.serde import deserialize_cdr

os.chdir('/media/kai/Kai_Backup/Master_Study/Master_Thesis/Master_Study_Master_Thesis/fr3_mujoco_ws')
bag_path = "trajectory_data_stohasticdelay"  # Path to the recorded bag file

poses = []

with Reader(bag_path) as reader:
    for connection, timestamp, rawdata in reader.messages():
        if connection.topic == '/local_robot/ee_pose':
            msg = deserialize_cdr(rawdata, connection.msgtype)
            
            # Extract pose data
            poses.append([
                msg.pose.position.x,
                msg.pose.position.y,
                msg.pose.position.z,
                timestamp * 1e-9 
            ])

poses = np.array(poses)


# Normalize time to start from 0
poses[:, 3] = poses[:, 3] - poses[0, 3]

fig = plt.figure(figsize=(16, 12))

# 3D trajectory
ax1 = fig.add_subplot(2, 3, 1, projection='3d')
ax1.plot(poses[:, 0], poses[:, 1], poses[:, 2], 'b-', linewidth=2)
ax1.scatter(poses[0, 0], poses[0, 1], poses[0, 2], c='green', s=100, label='Start')
ax1.scatter(poses[-1, 0], poses[-1, 1], poses[-1, 2], c='red', s=100, label='End')
ax1.set_xlabel('X (m)')
ax1.set_ylabel('Y (m)')
ax1.set_zlabel('Z (m)')
ax1.legend()
ax1.set_title('3D End-Effector Trajectory')

# XY plane view
ax2 = fig.add_subplot(2, 3, 2)
ax2.plot(poses[:, 0], poses[:, 1], 'b-', linewidth=2)
ax2.scatter(poses[0, 0], poses[0, 1], c='green', s=100, label='Start')
ax2.scatter(poses[-1, 0], poses[-1, 1], c='red', s=100, label='End')
ax2.set_xlabel('X (m)')
ax2.set_ylabel('Y (m)')
ax2.set_title('XY Plane View')
ax2.legend()
ax2.grid(True)
ax2.axis('equal')

# Workspace bounds
x_range = [np.min(poses[:, 0]), np.max(poses[:, 0])]
y_range = [np.min(poses[:, 1]), np.max(poses[:, 1])]
z_range = [np.min(poses[:, 2]), np.max(poses[:, 2])]

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_16226/3715463633.py:16: DeprecationWarning: Global serialization/deserialization functions have been replaced with
# explicit typestores.
#
# If you are deserializing messages from an AnyReader instance, simply
# use its `.deserialize(data, typename)` method.
#
# Otherwise instantiate a type store and use its methods:
#
# from rosbags.typesys import Stores, get_typestore
#
# typestore = get_typestore(Stores.ROS2_FOXY)
# typestore.deserialize_cdr(data, typename)
#   msg = deserialize_cdr(rawdata, connection.msgtype)

# %%
# Trajectory data for remote robot
import os
import numpy as np
import matplotlib.pyplot as plt
from rosbags.rosbag2 import Reader
from rosbags.serde import deserialize_cdr

os.chdir('/media/kai/Kai_Backup/Master_Study/Master_Thesis/Master_Study_Master_Thesis/fr3_mujoco_ws')
bag_path = "trajectory_data_stohasticdelay"  # Path to the recorded bag file

poses = []

with Reader(bag_path) as reader:
    for connection, timestamp, rawdata in reader.messages():
        if connection.topic == '/remote_robot/ee_pose':
            msg = deserialize_cdr(rawdata, connection.msgtype)
            
            # Extract pose data
            poses.append([
                msg.pose.position.x,
                msg.pose.position.y,
                msg.pose.position.z,
                timestamp * 1e-9 
            ])

poses = np.array(poses)


# Normalize time to start from 0
poses[:, 3] = poses[:, 3] - poses[0, 3]

fig = plt.figure(figsize=(16, 12))

# 3D trajectory
ax1 = fig.add_subplot(2, 3, 1, projection='3d')
ax1.plot(poses[:, 0], poses[:, 1], poses[:, 2], 'b-', linewidth=2)
ax1.scatter(poses[0, 0], poses[0, 1], poses[0, 2], c='green', s=100, label='Start')
ax1.scatter(poses[-1, 0], poses[-1, 1], poses[-1, 2], c='red', s=100, label='End')
ax1.set_xlabel('X (m)')
ax1.set_ylabel('Y (m)')
ax1.set_zlabel('Z (m)')
ax1.legend()
ax1.set_title('3D End-Effector Trajectory')

# XY plane view
ax2 = fig.add_subplot(2, 3, 2)
ax2.plot(poses[:, 0], poses[:, 1], 'b-', linewidth=2)
ax2.scatter(poses[0, 0], poses[0, 1], c='green', s=100, label='Start')
ax2.scatter(poses[-1, 0], poses[-1, 1], c='red', s=100, label='End')
ax2.set_xlabel('X (m)')
ax2.set_ylabel('Y (m)')
ax2.set_title('XY Plane View')
ax2.legend()
ax2.grid(True)
ax2.axis('equal')

# Workspace bounds
x_range = [np.min(poses[:, 0]), np.max(poses[:, 0])]
y_range = [np.min(poses[:, 1]), np.max(poses[:, 1])]
z_range = [np.min(poses[:, 2]), np.max(poses[:, 2])]

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_16226/2005941955.py:16: DeprecationWarning: Global serialization/deserialization functions have been replaced with
# explicit typestores.
#
# If you are deserializing messages from an AnyReader instance, simply
# use its `.deserialize(data, typename)` method.
#
# Otherwise instantiate a type store and use its methods:
#
# from rosbags.typesys import Stores, get_typestore
#
# typestore = get_typestore(Stores.ROS2_FOXY)
# typestore.deserialize_cdr(data, typename)
#   msg = deserialize_cdr(rawdata, connection.msgtype)

# %%
def synchronize_by_timestamp(bag_path="trajectory_data_nodelay"):
    """Synchronize local and remote data by closest timestamps."""
    
    local_data = []
    remote_data = []
    
    with Reader(bag_path) as reader:
        for connection, timestamp, rawdata in reader.messages():
            msg = deserialize_cdr(rawdata, connection.msgtype)
            time_sec = timestamp * 1e-9
            
            if connection.topic == '/local_robot/ee_pose':
                local_data.append([msg.pose.position.x, msg.pose.position.y, 
                                 msg.pose.position.z, time_sec])
            elif connection.topic == '/remote_robot/ee_pose':
                remote_data.append([msg.pose.position.x, msg.pose.position.y, 
                                  msg.pose.position.z, time_sec])
    
    local_data = np.array(local_data)
    remote_data = np.array(remote_data)
    
    # Synchronize by finding closest timestamps
    synchronized_pairs = []
    
    for i, remote_point in enumerate(remote_data):
        remote_time = remote_point[3]
        
        # Find closest local timestamp
        time_diffs = np.abs(local_data[:, 3] - remote_time)
        closest_idx = np.argmin(time_diffs)
        time_diff = time_diffs[closest_idx]
        
        # Only pair if timestamps are close (< 0.1s)
        if time_diff < 0.1:
            local_point = local_data[closest_idx]
            
            print(f"Pair {len(synchronized_pairs)}:")
            print(f"  LOCAL:  t={local_point[3]:.3f}s, pos=[{local_point[0]:.3f}, {local_point[1]:.3f}, {local_point[2]:.3f}]")
            print(f"  REMOTE: t={remote_time:.3f}s, pos=[{remote_point[0]:.3f}, {remote_point[1]:.3f}, {remote_point[2]:.3f}]")
            print(f"  Time diff: {time_diff:.3f}s")
            
            # Calculate spatial error
            spatial_error = np.linalg.norm(remote_point[:3] - local_point[:3])
            print(f"  Spatial error: {spatial_error:.3f}m ({spatial_error*1000:.1f}mm)")
            print()
            
            synchronized_pairs.append((local_point[:3], remote_point[:3], time_diff, spatial_error))
    
    # Calculate overall statistics
    if synchronized_pairs:
        errors = [pair[3] for pair in synchronized_pairs]
        time_diffs = [pair[2] for pair in synchronized_pairs]
        
        print(f"=== SYNCHRONIZATION RESULTS ===")
        print(f"Synchronized pairs: {len(synchronized_pairs)}")
        print(f"Average time difference: {np.mean(time_diffs):.3f}s")
        print(f"Max time difference: {np.max(time_diffs):.3f}s")
        print(f"Mean spatial error: {np.mean(errors):.3f}m ({np.mean(errors)*1000:.1f}mm)")
        print(f"RMS spatial error: {np.sqrt(np.mean(np.array(errors)**2)):.3f}m")
    
    return synchronized_pairs

# Run the synchronization
synchronized_data = synchronize_by_timestamp()
# Out:
# Pair 0:
#   LOCAL:  t=1752234703.158s, pos=[0.308, -0.001, 0.704]
#   REMOTE: t=1752234703.155s, pos=[0.308, -0.003, 0.710]
#   Time diff: 0.003s
#   Spatial error: 0.007m (6.6mm)
#
# Pair 1:
#   LOCAL:  t=1752234703.618s, pos=[0.308, -0.000, 0.703]
#   REMOTE: t=1752234703.617s, pos=[0.308, -0.002, 0.710]
#   Time diff: 0.000s
#   Spatial error: 0.007m (6.6mm)
#
# Pair 2:
#   LOCAL:  t=1752234704.079s, pos=[0.308, -0.000, 0.703]
#   REMOTE: t=1752234704.072s, pos=[0.308, -0.002, 0.710]
#   Time diff: 0.007s
#   Spatial error: 0.006m (6.5mm)
#
# Pair 3:
#   LOCAL:  t=1752234704.518s, pos=[0.308, -0.001, 0.704]
#   REMOTE: t=1752234704.521s, pos=[0.308, -0.002, 0.710]
#   Time diff: 0.003s
#   Spatial error: 0.007m (6.5mm)
#
# Pair 4:
#   LOCAL:  t=1752234705.039s, pos=[0.308, -0.001, 0.704]
#   REMOTE: t=1752234705.048s, pos=[0.308, -0.002, 0.710]
#   Time diff: 0.009s
#   Spatial error: 0.006m (6.2mm)
#
# Pair 5:
#   LOCAL:  t=1752234705.458s, pos=[0.308, -0.002, 0.704]
#   REMOTE: t=1752234705.466s, pos=[0.308, -0.002, 0.710]
#   Time diff: 0.008s
#   Spatial error: 0.006m (6.3mm)
#
# Pair 6:
#   LOCAL:  t=1752234705.938s, pos=[0.308, -0.002, 0.704]
#   REMOTE: t=1752234705.940s, pos=[0.308, -0.003, 0.710]
#   Time diff: 0.002s
#   Spatial error: 0.006m (6.4mm)
#
# Pair 7:
#   LOCAL:  t=1752234706.358s, pos=[0.308, -0.001, 0.704]
#   REMOTE: t=1752234706.349s, pos=[0.308, -0.003, 0.710]
#   Time diff: 0.009s
#   Spatial error: 0.007m (6.6mm)
#
# Pair 8:
#   LOCAL:  t=1752234706.778s, pos=[0.308, -0.001, 0.704]
#   REMOTE: t=1752234706.779s, pos=[0.308, -0.004, 0.710]
#   Time diff: 0.001s
#   Spatial error: 0.007m (7.0mm)
#
# Pair 9:
#   LOCAL:  t=1752234707.219s, pos=[0.308, -0.000, 0.704]
#   REMOTE: t=1752234707.220s, pos=[0.308, -0.004, 0.710]
#   Time diff: 0.001s
#   Spatial error: 0.007m (7.2mm)
#
# Pair 10:
#   LOCAL:  t=1752234708.191s, pos=[0.308, 0.001, 0.704]
#   REMOTE: t=1752234708.235s, pos=[0.308, -0.003, 0.710]
#   Time diff: 0.043s
#   Spatial error: 0.008m (7.7mm)
#
# Pair 11:
#   LOCAL:  t=1752234708.779s, pos=[0.319, 0.001, 0.671]
#   REMOTE: t=1752234708.798s, pos=[0.308, -0.003, 0.710]
#   Time diff: 0.019s
#   Spatial error: 0.041m (41.2mm)
#
# Pair 12:
#   LOCAL:  t=1752234709.271s, pos=[0.340, 0.001, 0.608]
#   REMOTE: t=1752234709.239s, pos=[0.308, -0.002, 0.710]
#   Time diff: 0.032s
#   Spatial error: 0.107m (106.7mm)
#
# Pair 13:
#   LOCAL:  t=1752234719.220s, pos=[0.473, 0.137, 0.306]
#   REMOTE: t=1752234719.136s, pos=[0.377, 0.023, 0.481]
#   Time diff: 0.084s
#   Spatial error: 0.229m (229.3mm)
#
# Pair 14:
#   LOCAL:  t=1752234719.773s, pos=[0.481, 0.118, 0.306]
#   REMOTE: t=1752234719.711s, pos=[0.381, 0.035, 0.453]
#   Time diff: 0.062s
#   Spatial error: 0.196m (196.0mm)
#
# Pair 15:
#   LOCAL:  t=1752234720.674s, pos=[0.493, 0.077, 0.306]
#   REMOTE: t=1752234720.769s, pos=[0.388, 0.059, 0.412]
#   Time diff: 0.095s
#   Spatial error: 0.151m (151.0mm)
#
# Pair 16:
#   LOCAL:  t=1752234721.278s, pos=[0.499, 0.048, 0.305]
#   REMOTE: t=1752234721.288s, pos=[0.395, 0.076, 0.395]
#   Time diff: 0.010s
#   Spatial error: 0.140m (140.2mm)
#
# Pair 17:
#   LOCAL:  t=1752234721.788s, pos=[0.502, 0.021, 0.305]
#   REMOTE: t=1752234721.826s, pos=[0.404, 0.094, 0.379]
#   Time diff: 0.038s
#   Spatial error: 0.143m (142.5mm)
#
# Pair 18:
#   LOCAL:  t=1752234729.515s, pos=[0.404, -0.135, 0.313]
#   REMOTE: t=1752234729.553s, pos=[0.498, 0.046, 0.312]
#   Time diff: 0.038s
#   Spatial error: 0.204m (204.1mm)
#
# Pair 19:
#   LOCAL:  t=1752234729.979s, pos=[0.394, -0.117, 0.314]
#   REMOTE: t=1752234730.016s, pos=[0.501, 0.025, 0.311]
#   Time diff: 0.037s
#   Spatial error: 0.178m (178.1mm)
#
# Pair 20:
#   LOCAL:  t=1752234730.462s, pos=[0.382, -0.088, 0.315]
#   REMOTE: t=1752234730.503s, pos=[0.504, 0.002, 0.311]
#   Time diff: 0.041s
#   Spatial error: 0.152m (152.0mm)
#
# Pair 21:
#   LOCAL:  t=1752234731.035s, pos=[0.368, -0.054, 0.317]
#   REMOTE: t=1752234731.105s, pos=[0.505, -0.026, 0.310]
#   Time diff: 0.069s
#   Spatial error: 0.141m (140.5mm)
#
# Pair 22:
#   LOCAL:  t=1752234740.070s, pos=[0.170, 0.126, 0.294]
#   REMOTE: t=1752234739.983s, pos=[0.410, -0.099, 0.326]
#   Time diff: 0.087s
#   Spatial error: 0.331m (330.7mm)
#
# Pair 23:
#   LOCAL:  t=1752234749.693s, pos=[0.224, -0.138, 0.305]
#   REMOTE: t=1752234749.644s, pos=[0.194, 0.129, 0.307]
#   Time diff: 0.049s
#   Spatial error: 0.268m (268.3mm)
#
# Pair 24:
#   LOCAL:  t=1752234750.609s, pos=[0.249, -0.111, 0.306]
#   REMOTE: t=1752234750.649s, pos=[0.199, 0.100, 0.302]
#   Time diff: 0.040s
#   Spatial error: 0.218m (217.6mm)
#
# Pair 25:
#   LOCAL:  t=1752234751.293s, pos=[0.269, -0.085, 0.306]
#   REMOTE: t=1752234751.227s, pos=[0.202, 0.079, 0.299]
#   Time diff: 0.066s
#   Spatial error: 0.177m (176.9mm)
#
# Pair 26:
#   LOCAL:  t=1752234756.694s, pos=[0.424, 0.156, 0.302]
#   REMOTE: t=1752234756.632s, pos=[0.217, -0.131, 0.310]
#   Time diff: 0.062s
#   Spatial error: 0.353m (353.4mm)
#
# Pair 27:
#   LOCAL:  t=1752234758.262s, pos=[0.455, 0.154, 0.301]
#   REMOTE: t=1752234758.186s, pos=[0.266, -0.094, 0.311]
#   Time diff: 0.076s
#   Spatial error: 0.312m (311.8mm)
#
# Pair 28:
#   LOCAL:  t=1752234758.723s, pos=[0.464, 0.144, 0.302]
#   REMOTE: t=1752234758.715s, pos=[0.286, -0.074, 0.312]
#   Time diff: 0.009s
#   Spatial error: 0.282m (281.7mm)
#
# Pair 29:
#   LOCAL:  t=1752234759.203s, pos=[0.473, 0.130, 0.302]
#   REMOTE: t=1752234759.201s, pos=[0.306, -0.051, 0.311]
#   Time diff: 0.002s
#   Spatial error: 0.246m (246.3mm)
#
# Pair 30:
#   LOCAL:  t=1752234759.725s, pos=[0.480, 0.113, 0.303]
#   REMOTE: t=1752234759.783s, pos=[0.327, -0.024, 0.310]
#   Time diff: 0.058s
#   Spatial error: 0.206m (205.6mm)
#
# Pair 31:
#   LOCAL:  t=1752234760.258s, pos=[0.487, 0.092, 0.303]
#   REMOTE: t=1752234760.194s, pos=[0.341, -0.004, 0.310]
#   Time diff: 0.064s
#   Spatial error: 0.175m (175.5mm)
#
# Pair 32:
#   LOCAL:  t=1752234762.340s, pos=[0.502, -0.011, 0.304]
#   REMOTE: t=1752234762.279s, pos=[0.401, 0.089, 0.306]
#   Time diff: 0.061s
#   Spatial error: 0.143m (142.5mm)
#
# Pair 33:
#   LOCAL:  t=1752234763.411s, pos=[0.501, -0.069, 0.304]
#   REMOTE: t=1752234763.493s, pos=[0.423, 0.119, 0.304]
#   Time diff: 0.081s
#   Spatial error: 0.203m (202.8mm)
#
# Pair 34:
#   LOCAL:  t=1752234774.416s, pos=[0.277, 0.120, 0.311]
#   REMOTE: t=1752234774.450s, pos=[0.464, -0.146, 0.314]
#   Time diff: 0.033s
#   Spatial error: 0.325m (324.8mm)
#
# Pair 35:
#   LOCAL:  t=1752234779.700s, pos=[0.152, 0.155, 0.302]
#   REMOTE: t=1752234779.651s, pos=[0.357, 0.039, 0.325]
#   Time diff: 0.049s
#   Spatial error: 0.237m (236.9mm)
#
# Pair 36:
#   LOCAL:  t=1752234780.324s, pos=[0.168, 0.118, 0.292]
#   REMOTE: t=1752234780.333s, pos=[0.338, 0.075, 0.325]
#   Time diff: 0.008s
#   Spatial error: 0.179m (178.9mm)
#
# Pair 37:
#   LOCAL:  t=1752234782.481s, pos=[0.180, -0.027, 0.284]
#   REMOTE: t=1752234782.550s, pos=[0.256, 0.167, 0.322]
#   Time diff: 0.068s
#   Spatial error: 0.212m (212.1mm)
#
# Pair 38:
#   LOCAL:  t=1752234783.001s, pos=[0.176, -0.054, 0.288]
#   REMOTE: t=1752234783.016s, pos=[0.239, 0.175, 0.321]
#   Time diff: 0.015s
#   Spatial error: 0.240m (240.0mm)
#
# Pair 39:
#   LOCAL:  t=1752234783.567s, pos=[0.172, -0.081, 0.292]
#   REMOTE: t=1752234783.637s, pos=[0.219, 0.177, 0.320]
#   Time diff: 0.070s
#   Spatial error: 0.264m (264.4mm)
#
# Pair 40:
#   LOCAL:  t=1752234784.139s, pos=[0.169, -0.105, 0.295]
#   REMOTE: t=1752234784.204s, pos=[0.205, 0.177, 0.318]
#   Time diff: 0.065s
#   Spatial error: 0.284m (284.4mm)
#
# Pair 41:
#   LOCAL:  t=1752234784.854s, pos=[0.166, -0.130, 0.298]
#   REMOTE: t=1752234784.900s, pos=[0.193, 0.173, 0.315]
#   Time diff: 0.046s
#   Spatial error: 0.305m (305.1mm)
#
# Pair 42:
#   LOCAL:  t=1752234785.562s, pos=[0.165, -0.149, 0.300]
#   REMOTE: t=1752234785.627s, pos=[0.185, 0.168, 0.312]
#   Time diff: 0.065s
#   Spatial error: 0.317m (317.3mm)
#
# Pair 43:
#   LOCAL:  t=1752234785.983s, pos=[0.167, -0.160, 0.301]
#   REMOTE: t=1752234786.046s, pos=[0.182, 0.161, 0.310]
#   Time diff: 0.063s
#   Spatial error: 0.322m (321.9mm)
#
# Pair 44:
#   LOCAL:  t=1752234786.582s, pos=[0.172, -0.168, 0.302]
#   REMOTE: t=1752234786.650s, pos=[0.182, 0.153, 0.307]
#   Time diff: 0.067s
#   Spatial error: 0.321m (321.3mm)
#
# Pair 45:
#   LOCAL:  t=1752234787.221s, pos=[0.180, -0.172, 0.303]
#   REMOTE: t=1752234787.198s, pos=[0.184, 0.142, 0.305]
#   Time diff: 0.023s
#   Spatial error: 0.314m (314.1mm)
#
# Pair 46:
#   LOCAL:  t=1752234787.951s, pos=[0.189, -0.171, 0.304]
#   REMOTE: t=1752234787.962s, pos=[0.192, 0.117, 0.301]
#   Time diff: 0.011s
#   Spatial error: 0.288m (288.3mm)
#
# Pair 47:
#   LOCAL:  t=1752234788.369s, pos=[0.199, -0.165, 0.304]
#   REMOTE: t=1752234788.444s, pos=[0.197, 0.096, 0.298]
#   Time diff: 0.075s
#   Spatial error: 0.261m (261.2mm)
#
# Pair 48:
#   LOCAL:  t=1752234788.929s, pos=[0.215, -0.152, 0.305]
#   REMOTE: t=1752234789.029s, pos=[0.204, 0.068, 0.297]
#   Time diff: 0.100s
#   Spatial error: 0.220m (219.9mm)
#
# Pair 49:
#   LOCAL:  t=1752234791.389s, pos=[0.285, -0.062, 0.306]
#   REMOTE: t=1752234791.456s, pos=[0.206, -0.052, 0.300]
#   Time diff: 0.067s
#   Spatial error: 0.080m (79.7mm)
#
# Pair 50:
#   LOCAL:  t=1752234791.988s, pos=[0.304, -0.033, 0.305]
#   REMOTE: t=1752234792.013s, pos=[0.203, -0.076, 0.302]
#   Time diff: 0.024s
#   Spatial error: 0.110m (110.1mm)
#
# Pair 51:
#   LOCAL:  t=1752234792.614s, pos=[0.323, -0.001, 0.305]
#   REMOTE: t=1752234792.587s, pos=[0.200, -0.098, 0.303]
#   Time diff: 0.027s
#   Spatial error: 0.157m (157.2mm)
#
# Pair 52:
#   LOCAL:  t=1752234793.241s, pos=[0.341, 0.030, 0.304]
#   REMOTE: t=1752234793.248s, pos=[0.197, -0.117, 0.305]
#   Time diff: 0.007s
#   Spatial error: 0.206m (205.8mm)
#
# Pair 53:
#   LOCAL:  t=1752234797.088s, pos=[0.431, 0.160, 0.301]
#   REMOTE: t=1752234797.022s, pos=[0.235, -0.130, 0.310]
#   Time diff: 0.066s
#   Spatial error: 0.351m (350.5mm)
#
# Pair 54:
#   LOCAL:  t=1752234799.382s, pos=[0.472, 0.131, 0.302]
#   REMOTE: t=1752234799.294s, pos=[0.290, -0.071, 0.311]
#   Time diff: 0.088s
#   Spatial error: 0.272m (272.3mm)
#
# Pair 55:
#   LOCAL:  t=1752234799.937s, pos=[0.480, 0.115, 0.302]
#   REMOTE: t=1752234799.986s, pos=[0.302, -0.053, 0.311]
#   Time diff: 0.049s
#   Spatial error: 0.245m (245.0mm)
#
# Pair 56:
#   LOCAL:  t=1752234806.630s, pos=[0.463, -0.169, 0.306]
#   REMOTE: t=1752234806.603s, pos=[0.445, 0.133, 0.304]
#   Time diff: 0.027s
#   Spatial error: 0.302m (302.5mm)
#
# Pair 57:
#   LOCAL:  t=1752234807.217s, pos=[0.451, -0.173, 0.307]
#   REMOTE: t=1752234807.233s, pos=[0.453, 0.133, 0.304]
#   Time diff: 0.016s
#   Spatial error: 0.306m (305.8mm)
#
# Pair 58:
#   LOCAL:  t=1752234807.728s, pos=[0.439, -0.172, 0.308]
#   REMOTE: t=1752234807.755s, pos=[0.462, 0.125, 0.305]
#   Time diff: 0.027s
#   Spatial error: 0.297m (297.1mm)
#
# Pair 59:
#   LOCAL:  t=1752234809.030s, pos=[0.411, -0.148, 0.310]
#   REMOTE: t=1752234809.000s, pos=[0.483, 0.079, 0.305]
#   Time diff: 0.031s
#   Spatial error: 0.238m (238.1mm)
#
# Pair 60:
#   LOCAL:  t=1752234809.600s, pos=[0.400, -0.129, 0.311]
#   REMOTE: t=1752234809.691s, pos=[0.491, 0.052, 0.306]
#   Time diff: 0.090s
#   Spatial error: 0.203m (203.3mm)
#
# Pair 61:
#   LOCAL:  t=1752234810.172s, pos=[0.387, -0.103, 0.311]
#   REMOTE: t=1752234810.182s, pos=[0.496, 0.030, 0.306]
#   Time diff: 0.009s
#   Spatial error: 0.172m (172.2mm)
#
# Pair 62:
#   LOCAL:  t=1752234810.752s, pos=[0.372, -0.071, 0.312]
#   REMOTE: t=1752234810.702s, pos=[0.500, 0.004, 0.306]
#   Time diff: 0.050s
#   Spatial error: 0.148m (147.9mm)
#
# Pair 63:
#   LOCAL:  t=1752234819.477s, pos=[0.162, 0.148, 0.296]
#   REMOTE: t=1752234819.517s, pos=[0.387, -0.037, 0.323]
#   Time diff: 0.040s
#   Spatial error: 0.293m (293.2mm)
#
# Pair 64:
#   LOCAL:  t=1752234820.178s, pos=[0.178, 0.100, 0.285]
#   REMOTE: t=1752234820.229s, pos=[0.372, -0.002, 0.323]
#   Time diff: 0.051s
#   Spatial error: 0.223m (223.1mm)
#
# Pair 65:
#   LOCAL:  t=1752234823.116s, pos=[0.172, -0.071, 0.288]
#   REMOTE: t=1752234823.199s, pos=[0.242, 0.165, 0.316]
#   Time diff: 0.083s
#   Spatial error: 0.248m (247.6mm)
#
# Pair 66:
#   LOCAL:  t=1752234832.149s, pos=[0.309, -0.025, 0.305]
#   REMOTE: t=1752234832.239s, pos=[0.198, -0.108, 0.300]
#   Time diff: 0.090s
#   Spatial error: 0.139m (139.2mm)
#
# Pair 67:
#   LOCAL:  t=1752234832.685s, pos=[0.326, 0.003, 0.305]
#   REMOTE: t=1752234832.730s, pos=[0.195, -0.121, 0.302]
#   Time diff: 0.045s
#   Spatial error: 0.181m (180.6mm)
#
# Pair 68:
#   LOCAL:  t=1752234835.371s, pos=[0.394, 0.123, 0.301]
#   REMOTE: t=1752234835.439s, pos=[0.205, -0.154, 0.308]
#   Time diff: 0.068s
#   Spatial error: 0.335m (335.4mm)
#
# Pair 69:
#   LOCAL:  t=1752234836.104s, pos=[0.409, 0.145, 0.301]
#   REMOTE: t=1752234836.040s, pos=[0.214, -0.150, 0.309]
#   Time diff: 0.063s
#   Spatial error: 0.354m (353.5mm)
#
# Pair 70:
#   LOCAL:  t=1752234840.452s, pos=[0.487, 0.094, 0.303]
#   REMOTE: t=1752234840.443s, pos=[0.343, 0.002, 0.308]
#   Time diff: 0.009s
#   Spatial error: 0.171m (170.8mm)
#
# Pair 71:
#   LOCAL:  t=1752234843.544s, pos=[0.502, -0.054, 0.304]
#   REMOTE: t=1752234843.485s, pos=[0.413, 0.112, 0.303]
#   Time diff: 0.059s
#   Spatial error: 0.188m (187.5mm)
#
# Pair 72:
#   LOCAL:  t=1752234844.149s, pos=[0.500, -0.079, 0.304]
#   REMOTE: t=1752234844.087s, pos=[0.424, 0.122, 0.303]
#   Time diff: 0.062s
#   Spatial error: 0.215m (215.5mm)
#
# Pair 73:
#   LOCAL:  t=1752234845.199s, pos=[0.487, -0.130, 0.305]
#   REMOTE: t=1752234845.110s, pos=[0.443, 0.129, 0.303]
#   Time diff: 0.088s
#   Spatial error: 0.263m (262.6mm)
#
# Pair 74:
#   LOCAL:  t=1752234847.813s, pos=[0.436, -0.168, 0.308]
#   REMOTE: t=1752234847.859s, pos=[0.493, 0.032, 0.306]
#   Time diff: 0.047s
#   Spatial error: 0.208m (208.5mm)
#
# Pair 75:
#   LOCAL:  t=1752234848.383s, pos=[0.423, -0.159, 0.309]
#   REMOTE: t=1752234848.447s, pos=[0.498, 0.004, 0.306]
#   Time diff: 0.064s
#   Spatial error: 0.179m (179.3mm)
#
# Pair 76:
#   LOCAL:  t=1752234851.067s, pos=[0.362, -0.049, 0.312]
#   REMOTE: t=1752234851.032s, pos=[0.489, -0.108, 0.310]
#   Time diff: 0.035s
#   Spatial error: 0.141m (140.6mm)
#
# Pair 77:
#   LOCAL:  t=1752234853.985s, pos=[0.282, 0.113, 0.310]
#   REMOTE: t=1752234853.959s, pos=[0.442, -0.144, 0.316]
#   Time diff: 0.027s
#   Spatial error: 0.302m (302.5mm)
#
# Pair 78:
#   LOCAL:  t=1752234854.498s, pos=[0.265, 0.137, 0.309]
#   REMOTE: t=1752234854.504s, pos=[0.432, -0.135, 0.317]
#   Time diff: 0.006s
#   Spatial error: 0.319m (319.3mm)
#
# Pair 79:
#   LOCAL:  t=1752234855.063s, pos=[0.248, 0.158, 0.308]
#   REMOTE: t=1752234855.070s, pos=[0.423, -0.122, 0.318]
#   Time diff: 0.006s
#   Spatial error: 0.330m (330.3mm)
#
# Pair 80:
#   LOCAL:  t=1752234855.589s, pos=[0.230, 0.175, 0.308]
#   REMOTE: t=1752234855.664s, pos=[0.412, -0.102, 0.319]
#   Time diff: 0.075s
#   Spatial error: 0.332m (331.6mm)
#
# Pair 81:
#   LOCAL:  t=1752234859.082s, pos=[0.157, 0.164, 0.303]
#   REMOTE: t=1752234859.025s, pos=[0.341, 0.067, 0.321]
#   Time diff: 0.058s
#   Spatial error: 0.208m (208.5mm)
#
# Pair 82:
#   LOCAL:  t=1752234859.597s, pos=[0.165, 0.138, 0.295]
#   REMOTE: t=1752234859.645s, pos=[0.323, 0.097, 0.320]
#   Time diff: 0.048s
#   Spatial error: 0.165m (165.0mm)
#
# Pair 83:
#   LOCAL:  t=1752234860.148s, pos=[0.178, 0.098, 0.287]
#   REMOTE: t=1752234860.208s, pos=[0.307, 0.122, 0.320]
#   Time diff: 0.060s
#   Spatial error: 0.135m (135.0mm)
#
# Pair 84:
#   LOCAL:  t=1752234861.397s, pos=[0.186, 0.018, 0.278]
#   REMOTE: t=1752234861.480s, pos=[0.260, 0.166, 0.317]
#   Time diff: 0.083s
#   Spatial error: 0.171m (170.6mm)
#
# Pair 85:
#   LOCAL:  t=1752234875.146s, pos=[0.379, 0.097, 0.302]
#   REMOTE: t=1752234875.146s, pos=[0.190, -0.136, 0.303]
#   Time diff: 0.001s
#   Spatial error: 0.300m (300.0mm)
#
# Pair 86:
#   LOCAL:  t=1752234887.574s, pos=[0.447, -0.168, 0.307]
#   REMOTE: t=1752234887.545s, pos=[0.439, 0.120, 0.304]
#   Time diff: 0.029s
#   Spatial error: 0.288m (288.1mm)
#
# Pair 87:
#   LOCAL:  t=1752234888.307s, pos=[0.432, -0.165, 0.308]
#   REMOTE: t=1752234888.307s, pos=[0.453, 0.114, 0.305]
#   Time diff: 0.000s
#   Spatial error: 0.280m (279.9mm)
#
# Pair 88:
#   LOCAL:  t=1752234889.273s, pos=[0.413, -0.150, 0.309]
#   REMOTE: t=1752234889.304s, pos=[0.468, 0.098, 0.305]
#   Time diff: 0.031s
#   Spatial error: 0.254m (253.8mm)
#
# Pair 89:
#   LOCAL:  t=1752234889.849s, pos=[0.400, -0.131, 0.310]
#   REMOTE: t=1752234889.906s, pos=[0.478, 0.081, 0.305]
#   Time diff: 0.057s
#   Spatial error: 0.226m (225.8mm)
#
# Pair 90:
#   LOCAL:  t=1752234891.236s, pos=[0.370, -0.060, 0.312]
#   REMOTE: t=1752234891.196s, pos=[0.491, 0.043, 0.306]
#   Time diff: 0.039s
#   Spatial error: 0.160m (160.0mm)
#
# Pair 91:
#   LOCAL:  t=1752234891.870s, pos=[0.354, -0.022, 0.312]
#   REMOTE: t=1752234891.907s, pos=[0.496, 0.028, 0.307]
#   Time diff: 0.037s
#   Spatial error: 0.151m (150.8mm)
#
# Pair 92:
#   LOCAL:  t=1752234893.315s, pos=[0.315, 0.060, 0.312]
#   REMOTE: t=1752234893.261s, pos=[0.501, -0.031, 0.308]
#   Time diff: 0.054s
#   Spatial error: 0.207m (207.0mm)
#
# Pair 93:
#   LOCAL:  t=1752234899.481s, pos=[0.163, 0.160, 0.299]
#   REMOTE: t=1752234899.577s, pos=[0.421, -0.108, 0.320]
#   Time diff: 0.096s
#   Spatial error: 0.372m (372.5mm)
#
# Pair 94:
#   LOCAL:  t=1752234900.220s, pos=[0.181, 0.109, 0.288]
#   REMOTE: t=1752234900.306s, pos=[0.408, -0.080, 0.322]
#   Time diff: 0.086s
#   Spatial error: 0.298m (297.9mm)
#
# Pair 95:
#   LOCAL:  t=1752234905.606s, pos=[0.166, -0.148, 0.299]
#   REMOTE: t=1752234905.568s, pos=[0.217, 0.174, 0.311]
#   Time diff: 0.037s
#   Spatial error: 0.326m (325.6mm)
#
# Pair 96:
#   LOCAL:  t=1752234906.113s, pos=[0.169, -0.159, 0.300]
#   REMOTE: t=1752234906.167s, pos=[0.209, 0.167, 0.307]
#   Time diff: 0.054s
#   Spatial error: 0.329m (328.8mm)
#
# Pair 97:
#   LOCAL:  t=1752234908.549s, pos=[0.203, -0.162, 0.304]
#   REMOTE: t=1752234908.501s, pos=[0.214, 0.100, 0.294]
#   Time diff: 0.047s
#   Spatial error: 0.262m (262.0mm)
#
# Pair 98:
#   LOCAL:  t=1752234909.050s, pos=[0.214, -0.152, 0.305]
#   REMOTE: t=1752234908.965s, pos=[0.217, 0.074, 0.292]
#   Time diff: 0.085s
#   Spatial error: 0.227m (227.0mm)
#
# Pair 99:
#   LOCAL:  t=1752234909.614s, pos=[0.232, -0.134, 0.305]
#   REMOTE: t=1752234909.580s, pos=[0.220, 0.036, 0.291]
#   Time diff: 0.034s
#   Spatial error: 0.171m (171.1mm)
#
# Pair 100:
#   LOCAL:  t=1752234917.812s, pos=[0.450, 0.160, 0.301]
#   REMOTE: t=1752234917.744s, pos=[0.270, -0.096, 0.310]
#   Time diff: 0.068s
#   Spatial error: 0.313m (312.5mm)
#
# Pair 101:
#   LOCAL:  t=1752234918.278s, pos=[0.458, 0.153, 0.301]
#   REMOTE: t=1752234918.315s, pos=[0.287, -0.075, 0.310]
#   Time diff: 0.037s
#   Spatial error: 0.286m (286.0mm)
#
# Pair 102:
#   LOCAL:  t=1752234918.813s, pos=[0.468, 0.142, 0.302]
#   REMOTE: t=1752234918.872s, pos=[0.304, -0.053, 0.310]
#   Time diff: 0.059s
#   Spatial error: 0.254m (254.5mm)
#
# Pair 103:
#   LOCAL:  t=1752234922.677s, pos=[0.503, -0.016, 0.304]
#   REMOTE: t=1752234922.714s, pos=[0.402, 0.103, 0.304]
#   Time diff: 0.037s
#   Spatial error: 0.156m (156.4mm)
#
# Pair 104:
#   LOCAL:  t=1752234925.179s, pos=[0.487, -0.132, 0.305]
#   REMOTE: t=1752234925.161s, pos=[0.442, 0.136, 0.304]
#   Time diff: 0.018s
#   Spatial error: 0.272m (271.5mm)
#
# Pair 105:
#   LOCAL:  t=1752234925.670s, pos=[0.478, -0.150, 0.305]
#   REMOTE: t=1752234925.648s, pos=[0.450, 0.134, 0.304]
#   Time diff: 0.021s
#   Spatial error: 0.285m (285.3mm)
#
# Pair 106:
#   LOCAL:  t=1752234936.022s, pos=[0.218, 0.184, 0.308]
#   REMOTE: t=1752234936.057s, pos=[0.428, -0.131, 0.318]
#   Time diff: 0.035s
#   Spatial error: 0.379m (378.6mm)
#
# Pair 107:
#   LOCAL:  t=1752234936.539s, pos=[0.203, 0.192, 0.307]
#   REMOTE: t=1752234936.571s, pos=[0.418, -0.112, 0.319]
#   Time diff: 0.031s
#   Spatial error: 0.372m (372.4mm)
#
# Pair 108:
#   LOCAL:  t=1752234937.054s, pos=[0.189, 0.195, 0.307]
#   REMOTE: t=1752234937.066s, pos=[0.409, -0.091, 0.320]
#   Time diff: 0.011s
#   Spatial error: 0.360m (360.4mm)
#
# Pair 109:
#   LOCAL:  t=1752234937.627s, pos=[0.176, 0.193, 0.307]
#   REMOTE: t=1752234937.593s, pos=[0.398, -0.062, 0.322]
#   Time diff: 0.034s
#   Spatial error: 0.339m (338.7mm)
#
# Pair 110:
#   LOCAL:  t=1752234938.147s, pos=[0.166, 0.188, 0.306]
#   REMOTE: t=1752234938.143s, pos=[0.386, -0.033, 0.322]
#   Time diff: 0.004s
#   Spatial error: 0.312m (311.7mm)
#
# Pair 111:
#   LOCAL:  t=1752234939.149s, pos=[0.155, 0.162, 0.302]
#   REMOTE: t=1752234939.176s, pos=[0.361, 0.028, 0.322]
#   Time diff: 0.027s
#   Spatial error: 0.246m (246.1mm)
#
# Pair 112:
#   LOCAL:  t=1752234939.720s, pos=[0.167, 0.128, 0.293]
#   REMOTE: t=1752234939.774s, pos=[0.345, 0.061, 0.321]
#   Time diff: 0.054s
#   Spatial error: 0.193m (193.2mm)
#
# Pair 113:
#   LOCAL:  t=1752234940.280s, pos=[0.179, 0.088, 0.285]
#   REMOTE: t=1752234940.317s, pos=[0.331, 0.087, 0.321]
#   Time diff: 0.036s
#   Spatial error: 0.156m (156.3mm)
#
# Pair 114:
#   LOCAL:  t=1752234941.785s, pos=[0.181, -0.005, 0.276]
#   REMOTE: t=1752234941.835s, pos=[0.258, 0.161, 0.317]
#   Time diff: 0.050s
#   Spatial error: 0.188m (187.5mm)
#
# Pair 115:
#   LOCAL:  t=1752234942.381s, pos=[0.177, -0.037, 0.281]
#   REMOTE: t=1752234942.462s, pos=[0.234, 0.171, 0.314]
#   Time diff: 0.081s
#   Spatial error: 0.219m (218.6mm)
#
# Pair 116:
#   LOCAL:  t=1752234943.107s, pos=[0.170, -0.070, 0.287]
#   REMOTE: t=1752234943.021s, pos=[0.221, 0.174, 0.312]
#   Time diff: 0.085s
#   Spatial error: 0.250m (249.6mm)
#
# Pair 117:
#   LOCAL:  t=1752234943.589s, pos=[0.166, -0.092, 0.292]
#   REMOTE: t=1752234943.504s, pos=[0.209, 0.172, 0.310]
#   Time diff: 0.085s
#   Spatial error: 0.269m (268.5mm)
#
# Pair 118:
#   LOCAL:  t=1752234946.353s, pos=[0.167, -0.169, 0.301]
#   REMOTE: t=1752234946.254s, pos=[0.197, 0.132, 0.297]
#   Time diff: 0.099s
#   Spatial error: 0.302m (302.1mm)
#
# Pair 119:
#   LOCAL:  t=1752234951.010s, pos=[0.277, -0.075, 0.306]
#   REMOTE: t=1752234951.047s, pos=[0.202, -0.081, 0.297]
#   Time diff: 0.037s
#   Spatial error: 0.076m (75.7mm)
#
# Pair 120:
#   LOCAL:  t=1752234951.585s, pos=[0.295, -0.047, 0.306]
#   REMOTE: t=1752234951.618s, pos=[0.198, -0.103, 0.300]
#   Time diff: 0.033s
#   Spatial error: 0.112m (111.7mm)
#
# Pair 121:
#   LOCAL:  t=1752234952.297s, pos=[0.313, -0.017, 0.305]
#   REMOTE: t=1752234952.277s, pos=[0.195, -0.119, 0.301]
#   Time diff: 0.020s
#   Spatial error: 0.157m (156.7mm)
#
# Pair 122:
#   LOCAL:  t=1752234953.369s, pos=[0.348, 0.042, 0.304]
#   REMOTE: t=1752234953.433s, pos=[0.193, -0.144, 0.304]
#   Time diff: 0.064s
#   Spatial error: 0.243m (242.6mm)
#
# Pair 123:
#   LOCAL:  t=1752234954.620s, pos=[0.380, 0.100, 0.302]
#   REMOTE: t=1752234954.581s, pos=[0.199, -0.155, 0.307]
#   Time diff: 0.039s
#   Spatial error: 0.312m (312.1mm)
#
# Pair 124:
#   LOCAL:  t=1752234955.173s, pos=[0.393, 0.120, 0.302]
#   REMOTE: t=1752234955.089s, pos=[0.205, -0.154, 0.308]
#   Time diff: 0.084s
#   Spatial error: 0.332m (332.3mm)
#
# Pair 125:
#   LOCAL:  t=1752234955.650s, pos=[0.404, 0.136, 0.301]
#   REMOTE: t=1752234955.608s, pos=[0.214, -0.150, 0.309]
#   Time diff: 0.042s
#   Spatial error: 0.344m (343.5mm)
#
# Pair 126:
#   LOCAL:  t=1752234956.264s, pos=[0.417, 0.151, 0.301]
#   REMOTE: t=1752234956.193s, pos=[0.225, -0.141, 0.310]
#   Time diff: 0.071s
#   Spatial error: 0.350m (349.5mm)
#
# Pair 127:
#   LOCAL:  t=1752234956.806s, pos=[0.427, 0.160, 0.301]
#   REMOTE: t=1752234956.831s, pos=[0.241, -0.128, 0.310]
#   Time diff: 0.025s
#   Spatial error: 0.343m (343.0mm)
#
# Pair 128:
#   LOCAL:  t=1752234957.296s, pos=[0.437, 0.162, 0.301]
#   REMOTE: t=1752234957.345s, pos=[0.256, -0.112, 0.311]
#   Time diff: 0.049s
#   Spatial error: 0.329m (329.2mm)
#
# Pair 129:
#   LOCAL:  t=1752234958.468s, pos=[0.459, 0.153, 0.301]
#   REMOTE: t=1752234958.565s, pos=[0.292, -0.070, 0.311]
#   Time diff: 0.097s
#   Spatial error: 0.279m (278.6mm)
#
# Pair 130:
#   LOCAL:  t=1752234962.341s, pos=[0.503, -0.015, 0.304]
#   REMOTE: t=1752234962.391s, pos=[0.398, 0.096, 0.304]
#   Time diff: 0.050s
#   Spatial error: 0.153m (152.7mm)
#
# === SYNCHRONIZATION RESULTS ===
# Synchronized pairs: 131
# Average time difference: 0.045s
# Max time difference: 0.100s
# Mean spatial error: 0.221m (221.2mm)
# RMS spatial error: 0.242m
# /tmp/ipykernel_16226/3581262405.py:9: DeprecationWarning: Global serialization/deserialization functions have been replaced with
# explicit typestores.
#
# If you are deserializing messages from an AnyReader instance, simply
# use its `.deserialize(data, typename)` method.
#
# Otherwise instantiate a type store and use its methods:
#
# from rosbags.typesys import Stores, get_typestore
#
# typestore = get_typestore(Stores.ROS2_FOXY)
# typestore.deserialize_cdr(data, typename)
#   msg = deserialize_cdr(rawdata, connection.msgtype)
